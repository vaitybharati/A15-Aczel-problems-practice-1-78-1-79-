# %% [markdown]
# # A15-Aczel problems practice (1-78, 1-79)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### 78. A country’s percentage approval of its citizens in European Union membership is given below.

# %% [raw]
# Ireland 78% Luxembourg 75% Netherlands 70%
# Belgium 68 Spain 62 Denmark 60
# Germany 58 Greece 57 Italy 52
# France 52 Portugal 48 Sweden 48
# Finland 40 Austria 39 Britain 37
#
# Find the mean, median, and standard deviation for the percentage approval. Compare the mean and median to the entire EU approval percentage 53%.

# %%
pa=pd.Series([78,68,58,52,40,75,62,57,48,39,70,60,52,48,37])

# %%
pa.mean()
# Out:
# 56.266666666666666

# %%
pa.median()
# Out:
# 57.0

# %%
pa.std()
# Out:
# 12.836703329942326

# %%
plt.boxplot(pa)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x26623b896a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x26623b89d60>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x26623b89340>],
#  'medians': [<matplotlib.lines.Line2D at 0x26623b98460>],
#  'fliers': [<matplotlib.lines.Line2D at 0x26623b98760>],
#  'means': []}

# %% [raw]
# Mean & median is comparable to entire EU approval percentage of 53%

# %% [markdown]
# #### 79. The following display is adapted from an article in Fortune. Interpret the chart, and find the mean and standard deviation of the data, viewed as a population

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Chart Interpretation: Apple stores is making highest Annual sales per square foot and Saks is making the lowest sales. Also the data received is left skewed.

# %%
sales=pd.Series([4032,2666,930,611,362])

# %%
sales.mean()
# Out:
# 1720.2

# %%
sales.std()
# Out:
# 1576.2617802890484

# %%
plt.boxplot(sales)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x26623c26af0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x26623c331f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x26623c26790>],
#  'medians': [<matplotlib.lines.Line2D at 0x26623c338b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x26623c33bb0>],
#  'means': []}
